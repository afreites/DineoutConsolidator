# %%
#Zomato Database Build

# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import time
from zkeys import zkey

# %%
#Declare variables
id_no = []
name = []
price_range = []
review = []
phone = []
reservations = []
rating = []
counter = 20
entity_ids=[87081, 89161, 87881, 87221, 87871, 87091]

# %%
#Assign API key
api = zkey
headers = {'user-key': api}

# %%
#Loop through subzones
for entity_id in subzones:
    start=1
    count=20
#Loop through two pages of results
    for c in range(4):
        url = f'https://developers.zomato.com/api/v2.1/search?entity_id={entity_id}&entity_type=subzone&start={start}&count={count}'
        print(url)
        response = requests.get(url, headers=headers)
        toronto= json.loads(response.text)

        #add a one second interval between queries
        time.sleep(1)

        #Populate the dataframe
        for r in toronto['restaurants']:
            restaurant=r['restaurant']
            id_no.append(restaurant['id'])
            name.append(restaurant['name'])
            print(name)
            price_range.append(restaurant['price_range'])
            phone.append(str(restaurant['phone_numbers']))
            reservations.append(str(restaurant['has_table_booking']))
            review.append(restaurant['user_rating']['votes'])
            rating.append(restaurant['user_rating']['aggregate_rating'])

        #set the next page to pull
        start = start+20
        count = count+20
# Out:
# https://developers.zomato.com/api/v2.1/search?entity_id=87081&entity_type=subzone&start=1&count=20
# ...

# %%
toronto_df= pd.DataFrame(data={"name":name, "id": id_no, "phone": phone, "reservations": reservations, 
                              "price_range": price_range, "review": review, "rating": rating })
toronto_df=toronto_df.sort_values('id')
toronto_df.head(25)
# Out:
#                                         name        id  \
# 101                   Queen Street Warehouse  16500034
# 394                         Saravanaa Bhavan  16500067
# 447                         Ted's Restaurant  16500068
# 391                      Moxie's Grill & Bar  16500635
# 433                       Korean Grill House  16500670
# 435                             Jack Astor's  16500677
# 155                              Copa By Sea  16527238
# 130                               La Carnita  16529190
# 307                                    Diwan  16529504
# 226                                   Nadège  16529505
# 329                                      R&D  16539752
# 206                      M Square Coffee Co.  16541036
# 230                            Kupfert & Kim  16541046
# 229                   Jelly Modern Doughnuts  16542672
# 410  The Keg Steakhouse + Bar - Estate Drive  16547460
# 338                           The Dirty Bird  16547772
# ...

# %%
print(len(toronto_df))
# Out:
# 540

# %%
phones = toronto_df['phone']

# %%
phones_new = phones.str.split(',').str[0]

# %%
phones_new = [p.replace(' (', '') for p in phones_new]
phones_new = [p.replace(') ', '') for p in phones_new]
phones_new = [p.replace('-', '') for p in phones_new]

# %%
print (phones_new)
# Out:
# ['+16473447326', '+14162937755', '+14162822204', '+14162968803', '+14167548141', '+14162960965', '+16477483210', '+16473481066', '+14166464670', '+14163682009', '+14165861241', '+16473506444', '+14166011333', '+14165042056', '+14164381452', '+16473542473', '(035157 5307', '(035956 7200', '(089948 1373', '(024472 6687', '(024473 5555', '0417 979 960', '+14166361230', '+14162602222', '+16473466246', '+14162166767', '+14163911424', '+14162984153', '+14169168101', '+16473477713', '+14165021112', '+14162216789', '+14165960063', '+14169959639', '+16473481166', '+16473463888', '+14162387450', '+14163518000', 'Not available for this place', '+16477482886', '03 9070 8109', '+14162296191', '+14162983828', '+14165992855', '+14167563311', '+14165073378', '+16473514747', '+14162969697', '+14166468800', '+14167928628', '+14169410000', '22 0124175', '68373322', '62356133', '+12505725753', '+16473612025', '+14379222337', '+91 9982475601', '0423 2244000', '0135 2632131', '+91 8126383273', 'Not availa
# ...

# %%
toronto_df['phone'] = phones_new
toronto_df.head(25)
# Out:
#                                         name        id         phone  \
# 101                   Queen Street Warehouse  16500034  +16473447326
# 394                         Saravanaa Bhavan  16500067  +14162937755
# 447                         Ted's Restaurant  16500068  +14162822204
# 391                      Moxie's Grill & Bar  16500635  +14162968803
# 433                       Korean Grill House  16500670  +14167548141
# 435                             Jack Astor's  16500677  +14162960965
# 155                              Copa By Sea  16527238  +16477483210
# 130                               La Carnita  16529190  +16473481066
# 307                                    Diwan  16529504  +14166464670
# 226                                   Nadège  16529505  +14163682009
# 329                                      R&D  16539752  +14165861241
# 206                      M Square Coffee Co.  16541036  +16473506444
# 230                            Kupfert & Kim  16541046  +14166011333
# ...

# %%
#Save to a CSV all data retrieved
toronto_df.to_csv("zomato_toronto.csv", sep=',',index=False)

#Save a CSV with the telephone numbers to use in google pull
#toronto_df['phone'].to_csv('zomato_phone.csv', sep =',', )

# %%
import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import create_engine
engine = create_engine("mysql://root:367Tanner#@localhost/restaurant_review")

# %%
toronto_df.dtypes
# Out:
# name            object
# id              object
# phone           object
# reservations    object
# price_range      int64
# review          object
# rating          object
# dtype: object

# %%
toronto_df.to_sql(
                name='zomato',
                con=engine, 
                if_exists="append"
                 )
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# /Applications/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#
# /Applications/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
# ...
